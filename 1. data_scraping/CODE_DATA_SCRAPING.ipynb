# %%
from bs4 import BeautifulSoup
from playwright.sync_api import sync_playwright
import pandas as pd
import numpy as np
import os
import threading

def fighters_subpage_url_scraper():
    base_fighter_url = 'http://ufcstats.com/statistics/fighters?char=' # + str(letter)
    alphabet = 'abcdefghijklmnopqrstuvwxyz'
    subpage_url_suffice = '&page=all'

    alphabetized_urls = []
    for letter in alphabet:
        alphabetized_urls.append(base_fighter_url + str(letter) + subpage_url_suffice)

    return alphabetized_urls

def single_fighter_scraper(html):
    soup = BeautifulSoup(html, "html.parser")
    fighter_soup = soup.find('section', class_ = 'b-statistics__section_details')

    #For record
    heading_soup = soup.find('h2')
    record_unclean = heading_soup.find('span', class_ = 'b-content__title-record').text.strip()
    record = record_unclean[8:]
    df_record = pd.DataFrame([record], columns = ['record'])

    #For fight table
    fight_columns = [column.text.strip() for column in fighter_soup.find_all('th')]
    fight_rows = fighter_soup.find_all('tr')

    fight_data = []
    fight_ids = []
    for row in fight_rows:
        cells = row.find_all('td')
        clean_cell = [cell.text.strip() for cell in cells]
        if len(clean_cell) < len(fight_columns):
            clean_cell += [None] * (len(fight_columns) - len(clean_cell))
        
        fight_data.append(clean_cell)

        link = row.get('data-link')
        fight_ids.append(id_from_url(link) if link else None)

    '''
    AI FIX for if then above
    '''
    
    df_fight_table = pd.DataFrame(fight_data, columns = fight_columns)
    df_fight_table.insert(0, 'fight_id', fight_ids)
    
    #For biostats table
    biostats_table_soup = fighter_soup.find('ul')
    biostats_columns = [column.text.strip() for column in biostats_table_soup.find_all('i', class_ = 'b-list__box-item-title b-list__box-item-title_type_width')]

    biostats_data = []
    for i in range(len(biostats_columns)):
        biostats_data.append(biostats_table_soup.find_all('i', class_ = 'b-list__box-item-title b-list__box-item-title_type_width')[i].next_sibling.strip())
    df_biostats_table = pd.DataFrame([biostats_data], columns = biostats_columns)


    #For career statistics table
    career_stat_soup = fighter_soup.find('div', class_="b-list__info-box-left")
    career_stat_columns = [column.text.strip() for column in career_stat_soup.find_all('i')]

    career_stat_data = []
    for i in range(len(career_stat_columns)):
        career_stat_data.append(career_stat_soup.find_all('i')[i].next_sibling.strip())
    df_career_stat = pd.DataFrame([career_stat_data], columns = career_stat_columns)

    df_fighter_stats = pd.concat([df_record, df_career_stat, df_biostats_table], axis = 1).drop(columns=["Career statistics:"])
    
    return df_fighter_stats, df_fight_table

def single_fight_scraper(html):

    soup = BeautifulSoup(html, "html.parser")
    fight_soup = soup.find('div', class_ = 'b-fight-details')


    #For winner/loser/draw info:
    ordered_winner_result = [result.text.strip() for result in fight_soup.find_all('i', class_ = 'b-fight-details__person-status')]
    ordered_fighter_result = [result.text.strip() for result in fight_soup.find_all('a', class_ = 'b-link b-fight-details__person-link')]

    for i in range(2):
        if ordered_winner_result[i] == 'D':
            winner = 'TIE'
            loser = 'TIE'
        elif ordered_winner_result[i] == 'W':
            winner = ordered_fighter_result[i]
        else:
            loser = ordered_fighter_result[i]


    #For fight_details
    fight_details_soup = soup.find('p', class_ = 'b-fight-details__text')
    fight_details_columns = [column.text.strip() for column in fight_details_soup.find_all('i', class_ = 'b-fight-details__label')]

    fight_details_data = []

    fight_details_first_soup = fight_details_soup.find('i', class_ = "b-fight-details__text-item_first")
    fight_details_data.append(fight_details_first_soup.find('i', style="font-style: normal").text.strip())
    labels = fight_details_soup.find_all('i', class_ = 'b-fight-details__label')

    for column in labels:
        fight_details_data.append(column.next_sibling.text.strip())

    fight_details_data.pop(1) #remove blank space
    fight_details_columns.pop(4) #remove referee, since irrelevant
    fight_details_data.pop(4) #removes referee since irrelevant
    df_fight_details = pd.DataFrame([fight_details_data], columns = fight_details_columns)


    #round_by_round table
    rbr_soup = fight_soup.find('tr', class_ = "b-fight-details__table-row") # round by round soup
    rbr_columns = [column.text.strip() for column in rbr_soup] #has '' empty strings
    rbr_columns = [column for column in rbr_columns if column != ''] #removes empty strings

    rbr_fight_data_soup = fight_soup.find_all('section', class_ = "b-fight-details__section js-fight-section")[1]
    rbr_fight_datacell_soup = [column.text.strip() for column in rbr_fight_data_soup.find_all('p', class_ = "b-fight-details__table-text")]

    fighter_one_data = rbr_fight_datacell_soup[::2]
    fighter_two_data = rbr_fight_datacell_soup[1::2]

    df_rbr_total = pd.DataFrame(([fighter_one_data, fighter_two_data]), columns = rbr_columns)

    #aggregate fight table
    #round by round table
    #aggregate significant strikes table
    #round by round sig strikes table

    sections = fight_soup.find_all('section', class_="b-fight-details__section js-fight-section")

    index = [1, 2, 4]
    for i in index:
        section = sections[i]

        rbr_soup = section.find('tr', class_="b-fight-details__table-row")
        rbr_columns = [column.get_text(strip=True) for column in rbr_soup.find_all(['th', 'td'])]

        rbr_data = sections[i].find_all('p', class_="b-fight-details__table-text")
        rbr_data = [column.text.strip() for column in rbr_data]

        fighter_one_data = rbr_data[::2]
        fighter_two_data = rbr_data[1::2]
    
        arr_one = np.array(fighter_one_data)
        arr1 = arr_one.reshape(len(arr_one) // len(rbr_columns), len(rbr_columns))
        df_fighter_one = pd.DataFrame(arr1, columns=rbr_columns)

        arr_two = np.array(fighter_two_data)
        arr2 = arr_two.reshape(len(arr_two) // len(rbr_columns), len(rbr_columns))
        df_fighter_two = pd.DataFrame(arr2, columns=rbr_columns)

        if i == 1:
            df_aggregate_fight_1 = df_fighter_one
            df_aggregate_fight_2 = df_fighter_two
        if i == 2:
            df_rbr_fight_1 = df_fighter_one
            df_rbr_fight_2 = df_fighter_two
        if i == 4:
            df_sig_strikes_rbr_1 = df_fighter_one
            df_sig_strikes_rbr_2 = df_fighter_two


    #SCHEMA for TABLE

    df_rbr_fight_1.columns = ['Fighter','KD','Sig. str.','Sig. str. %','Total str.','Td','Td %','Sub. att','Rev.','Ctrl'] #reset scraping column names, scraped an error
    df_rbr_fight_2.columns = ['Fighter','KD','Sig. str.','Sig. str. %','Total str.','Td','Td %','Sub. att','Rev.','Ctrl'] #reset scraping column names, scraped an error

    df_aggregate_fight_1["Round"] = 0 #initialized round number
    df_aggregate_fight_2["Round"] = 0

    df_rbr_fight_1['Round'] = df_rbr_fight_1.index + 1
    df_rbr_fight_2['Round'] = df_rbr_fight_2.index + 1


    df_rounds_nonstrikes = pd.concat([df_aggregate_fight_1, df_rbr_fight_1, df_aggregate_fight_2, df_rbr_fight_2], axis = 0) #made composite table

    df_rbr_total['Round'] = 0
    df_sig_strikes_rbr_1['Round'] = df_sig_strikes_rbr_1.index + 1
    df_sig_strikes_rbr_2['Round'] = df_sig_strikes_rbr_2.index + 1

    df_rounds_strikes = pd.concat([df_rbr_total, df_sig_strikes_rbr_1, df_sig_strikes_rbr_2], axis = 0)
    df_rbr_fight  = pd.merge(df_rounds_nonstrikes, df_rounds_strikes, on = ['Fighter', 'Round'])


    df_winner = pd.DataFrame({"winner": [winner], 'loser': [loser]})
    df_fight_stats = pd.concat([df_fight_details, df_winner], axis = 1)

    return  df_fight_stats, df_rbr_fight
  
def fighter_url_scraper(subpage_html):

    soup = BeautifulSoup(subpage_html, "html.parser")

    row_soup = soup.find_all('tr', class_ = "b-statistics__table-row")
    fighter_urls = []

    for row in row_soup:
        a_tag = row.find('a')
        if a_tag:
            link = a_tag['href']
            fighter_urls.append(link)

    return fighter_urls

def single_raw_html_fetcher(url, page):
    page.goto(url, wait_until="domcontentloaded")
    try:
        page.wait_for_selector("body .l-page, table, tbody", timeout=15000)
    except:
        pass
    page.wait_for_timeout(200)
    html = page.content()
    return html

def events_page_scraper(page):
    url = 'http://ufcstats.com/statistics/events/completed?page=all'
    html = single_raw_html_fetcher(url, page)
    soup = BeautifulSoup(html, "html.parser")

    soup = soup.find('table', class_ = "b-statistics__table-events")
    row_soup = soup.find_all('a', class_ = 'b-link b-link_style_black')

    event_urls = []
    for row in row_soup:
        link = row.get('href')
        if link:
            event_urls.append(link)
    
    return event_urls

def fight_url_scraper(event_urls_list, page):

    fight_urls = []
    for url in event_urls_list:
        html = single_raw_html_fetcher(url, page)
        soup = BeautifulSoup(html, "html.parser")


        event_soup = soup.find('tbody', class_ = "b-fight-details__table-body")
        row_soup = event_soup.find_all('tr')

        for row in row_soup:
            link = row.get('data-link')
            if link:
                fight_urls.append(link)

    fight_urls = list(set(fight_urls)) # precautionary dedupe after iteration...
    return fight_urls

def save_progress(df, filename):
    df.to_csv( filename, mode="a", header=not os.path.exists(filename), index=False )

def id_from_url(url):
    return url.rstrip('/').split('/')[-1]

#

# %%
#Data Pipeline

def run_pipeline():
    p = sync_playwright().start()
    browser = p.chromium.launch(headless=True)
    page = browser.new_page()

    #Fighters pipeline
    subpage_urls_list = fighters_subpage_url_scraper()
    all_fighter_urls = []

    for i in range(len(subpage_urls_list)):
        all_fighter_urls.extend(fighter_url_scraper(single_raw_html_fetcher(subpage_urls_list[i], page)))

    pd.DataFrame(all_fighter_urls, columns=['fighter_url']).to_csv("all_fighter_urls.csv", index=False)

    for url in all_fighter_urls:
        try:
            df1, df2 = single_fighter_scraper(single_raw_html_fetcher(url, page))
            fid = id_from_url(url)
            df1.insert(0, 'fighter_id', fid)
            df2.insert(0, 'fighter_id', fid)
            save_progress(df1, "fighter_stats.csv")
            save_progress(df2, "fighter_fights.csv")
        except Exception as e:
            print(f"skip fighter {url}: {e}")
            df_fail = pd.DataFrame([[url, str(e)]], columns=['url', 'error'])
            save_progress(df_fail, "failed_fighters.csv")

    #Fights pipeline
    events_urls = events_page_scraper(page)
    complete_fight_urls = fight_url_scraper(events_urls, page)

    pd.DataFrame(events_urls, columns=['event_url']).to_csv("all_events_urls.csv", index=False)

    for url in complete_fight_urls:
        try:
            df3, df4 = single_fight_scraper(single_raw_html_fetcher(url, page))
            fid = id_from_url(url)
            df3.insert(0, 'fight_id', fid)
            df4.insert(0, 'fight_id', fid)
            save_progress(df3, "fight_oneline_stats.csv")
            save_progress(df4, "fights_roundbyround.csv")
        except Exception as e:
            print(f"skip fight {url}: {e}")
            df_fail = pd.DataFrame([[url, str(e)]], columns=['url', 'error'])
            save_progress(df_fail, "failed_fights.csv")


    page.close()
    browser.close()
    p.stop()

t = threading.Thread(target=run_pipeline)
t.start(); t.join()

# Build missing list and scrape to new csv for version control

scraped = set(pd.read_csv("fight_oneline_stats.csv")["fight_id"])
failed  = set(pd.read_csv("failed_fights.csv")["url"].str.rstrip('/').str.split('/').str[-1])
known   = set(pd.read_csv("fighter_fights.csv")["fight_id"].dropna())

missing_urls = ["http://ufcstats.com/fight-details/" + i for i in (known - scraped - failed)]
print(f"scraping {len(missing_urls)} missing fights")

def run_missing():
    p = sync_playwright().start()
    browser = p.chromium.launch(headless=True)
    page = browser.new_page()

    for url in missing_urls:
        try:
            df3, df4 = single_fight_scraper(single_raw_html_fetcher(url, page))
            fid = id_from_url(url)
            df3.insert(0, 'fight_id', fid)
            df4.insert(0, 'fight_id', fid)
            save_progress(df3, "missing_fight_oneline_stats.csv")
            save_progress(df4, "missing_fights_roundbyround.csv")
        except Exception as e:
            print(f"skip {url}: {e}")
            save_progress(pd.DataFrame([[url, str(e)]], columns=['url','error']),
                          "missing_failed_fights.csv")

    page.close(); browser.close(); p.stop()

t = threading.Thread(target=run_missing); t.start(); t.join()
# Out:
# skip fight http://ufcstats.com/fight-details/a5c90086fb65f58e: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/a1db4c917777aa79: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/80cb366cd1e54aec: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/7ada9af99946d456: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/ccacbe6a4c31cd45: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/83414cc83ec3f2ac: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/64756e0f4b305da8: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/92b98afec5eb4e05: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "http://ufcstats.com/fight-details/92b98afec5eb4e05", waiting until "domcontentloaded"
#
# skip fight http://ufcstats.com/fight-details/61d89fc97e7b145c: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/8e03db41687d9132: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/fe6b45e7210bfa8e: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/74256b4e8d0b1de6: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/9a2d3ebab827d333: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/629655f9b898810d: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/2c13b938e0f8190b: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/0fcf42b68f2f0fa3: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/77bf1e37929b0d59: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/1cad3dc6d7eccdfb: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/39dccca8e8083072: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/48e51d4e7172048e: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/d93c8c77e1091a16: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/c413b0abc04358c3: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/0019ec81fd706ade: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/e1bb0b615c02d715: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/819af4bbad55324d: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/651da45cc83ce011: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/bb59b82bddc96cca: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/46fa8e79fe8a9539: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/a7fd9da657bbce8e: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/62acea88e628c3ca: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/ceac6997d22f2f3b: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/f3100979573e2895: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/633fbb0894c002d2: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/821960adf5bfa15c: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/9d4b2767f6630fc9: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/6b30fe49b6df63de: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/ab18079c7c0040fb: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/f59b1215176636f6: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/dc48627a5f2daba9: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/7d0874323bd1f768: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/ce151e053721fe69: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/8208afe1e52b02e9: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/7ffdaa44fc8d111b: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/407e1c6850e7022c: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/2750ac5854e8b28b: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/7601245171a28da1: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/c9eb00b7efdc7559: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/0d1af8c6a5793185: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/65b4d4be2d04bb34: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/f1a9c3187855155c: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/3badedeb2c5533f4: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/57ff0eb2351979c4: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/934c967872f28b13: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/e3a2bf2d9ee83318: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/287c71b9017c5769: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/13e2ff8b3a122094: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/6390c8e74630473e: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/2874ea5d2f783e23: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/c47cf097227cc6a0: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/565ecefd8a37ad7e: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/f044802db5688bbe: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/2f449bd58b3d9a99: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/91daeeeea0a83e49: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/7ffcc3a72e082ace: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/6e5a3d6b6ed84ac3: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/c0568b225d5f0fe6: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/b80872821bc4f6ba: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/5d3e046b6bcd49f5: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/b297c3e938e1005e: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/5ab286735ccee803: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/6449a1a9a69a830c: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/5a2b86570110191b: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/04d37c1c206c0efd: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/9cdfcd164b48f55e: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/4b334c9727eee450: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/6cd542650d886c22: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/fe60fd0ee67902dc: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/b80e6a799c95d499: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/8b258bbb37f74a66: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/4bce0ce561a65288: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/b78545b32a97ac44: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/640d52630f4f8a61: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/4622ec182e7fed6b: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/635fbf57001897c7: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/96eaf07b34538b8b: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/b068a4ee6d842606: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/28255055879685bc: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/346875f19aefc88d: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/b2857e799319f931: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/93ffadd9e41af797: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/5701dbbbfa4f8313: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/aa161809e78bef96: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/5ab2a4fec735e0b2: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/415ea2520b7ba720: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/8ae79d7967681db8: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/f4e490d25bd62d39: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/58450502a93454c8: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/443791a8c6790cf0: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/7e8749cbf32ef1f8: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/be70a2f68f6ad3e7: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/e4fe950846b51bdf: 'NoneType' object is not iterable
# skip fight http://ufcstats.com/fight-details/7e27d9f37c217b63: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/53343bd123bcf651: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/da3210cd829fceb7: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/9968d308e97c6531: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/969aa613824c5dfe: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/b25662d83e6d4c3b: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/2aa175f3ebffcdf2: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/aa6a9aeeb45577d4: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/a6245f48fc60bc6a: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/73370221b3fa3676: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/6fe9729cee57c680: cannot access local variable 'winner' where it is not associated with a value
# skip fight http://ufcstats.com/fight-details/d822ebc7dbc6c259: cannot access local variable 'winner' where it is not associated with a value

# %%
# Out:
# scraping 2619 missing fights
# skip http://ufcstats.com/fight-details/8bfcaa85e06dc84b: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/6cca675fbec5a9ca: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/f74f1e8602cf18d6: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/c86a90967b123d31: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/2d9e2fde9c264f4f: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/ffe9356d2fe656f3: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/1e440a1425f1d0a7: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/f385d0fc49095e55: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/577d8e25cf71566c: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/39376c02e064944e: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/f2e14ec18f3b6672: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/e5475f2cf5b74531: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/69f0b5f253d42c3d: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/79aebe1a1f24a116: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/3bfb931e73e53f68: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/54c58e879d0a8d36: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/9e1836b84e5465de: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/ca22594226b2dcc6: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/7bcfe834f0a5bce7: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/0953c5573290719a: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/fa004e713a7d0898: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/237523159112894e: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/c28d8ffbb8fd3e9e: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/5e6ab3c7d664daa7: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/6f808a147a2ad9f1: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/5b6ac309667e7c3b: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/93d033a4d45e8ec7: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/509a6dfd520dcb15: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/1ac0a44f1627f05d: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/4711c195cc941c78: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/2144d4e090b15e55: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/6011e1849dcd5a29: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/b31af4ba792c9d19: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/b90c89220d2f7d3d: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/f3000eff02664be4: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/a2183e15c612471d: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/10e689c81935dd40: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/9e912e4905a19a75: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/c70c214b3eac2b93: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/8789acd6479f7b31: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/8e1dafaf40d0aea0: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/a4c7c6c92123bf1e: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/66788700e92a6a2f: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/16ba84ab35415c54: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/ac8ac7fcbdf2f9fe: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/c2764af250e03bf8: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/802c28015de08bd3: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/381cee4b3af63ade: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/994f97a075a1b600: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/c6cb0d84501c98d3: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/ca66e28f1d4f8125: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/bbf93892f1a9017c: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/682bb08c23dd86d1: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/adc668bb94ef2e30: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/96c5470d4dbc39fb: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/a9418e446839adc0: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/53411e3d56d58ec9: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/8cefea96a5f67fc9: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/3bbbd72872122cd6: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/d8184daf8ec873fa: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/6035a68279b69aeb: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/3286db65cf6fa265: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/5216d14d649ed5db: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/b45aae9776bd9a6d: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/9b3b15de4c8d9029: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/5618bcff9d742d85: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/8769e5db66707269: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/41726ad856e7becb: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/3766208fdbc20d32: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/ce32437750074a04: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/bf4fd0c8bb7b634c: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/05116b90ab6eb023: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/badfa1ceb1d9662c: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/f8c32b83d746ef4a: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/39c0c09f8976dafa: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/30cbe5ff6b997f8e: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/0da3374a61e7d102: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/b361da093a16a614: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/793b0aeab7015346: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/9be14b958737f074: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/5511eaf7873c4a21: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/26024189488b22a5: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/4b97406fa671a438: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/98f15526cc0a461c: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/a2a34b7875a79ca1: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/339b8d0fe27e1603: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/713f44a1e2deaae4: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/5116d22da5be2ffa: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/c4b79df91cdd4447: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/30709acd9d024680: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/432d023d03add311: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/1c0fba5b885e8a15: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/982eea5a54537892: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/2f5e1c2bb8dec84b: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/2b39788a4f9530d1: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/5735250a204e2d47: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/ec2ceffc80b80fb8: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/e821a0960a9dac35: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/d68458d7ceeae267: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/9dfbd2badf98ad35: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/272f300e7c598e05: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/dd821478446b6c78: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/eb8a108217b234cb: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/7d04116c1d12ea11: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/6e56bce310375396: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/4d8c89f5dde017da: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/319640b7e4a7ff44: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/f3e8d68765b2a75d: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/01d1432bdc132de1: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/d781ee8ef1a4bb65: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/8ae1d7d789476d4c: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/417c185bcf76408f: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/93908423a3e7c251: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/8bc13c385e828260: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/010b638fd558699a: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/eb460412c805f220: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/f6b66c307423061c: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/79438e61641cce04: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/0c04a9b641f4a3c3: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/36cf2a8849a4a6ff: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/a33a807420802954: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/df8d4ceb9239f2f8: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/34ce39dcc45787c6: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/ac1643d70b0b984c: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/80baa3ae3092693d: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/704cf5fe7c155e66: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/9d3b1af3fbbfa381: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/7ae8467e67ea5b29: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/74b5745fa01bb350: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/9f923cf0420518e6: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/529b8ef33e81f219: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/608fb46a1ec8c5ae: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/5c8b91073cc25f33: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/3b41b638b6358274: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/2e44c51dd9cf3910: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/98d15e32630438d8: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/5751cf88f3e4a126: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/04ab1542925032ea: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/142123c2446b2582: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/6789480d7daea557: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/89229d26e5a75a32: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/0168a8cd8315e59e: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/670915f96aa81e03: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/75f519c5c6210bac: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/1206dc7d5228f5bd: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/a434830b1f2c43fc: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/b2f7d2ff9b35d3b4: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/4fb8347a5c424198: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/3a84cfc412e5e12a: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/dcec9cc0f4ac8f95: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/782dc9eeaf21fd48: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/c9602f3ebb62d941: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/4e0b7cd687a2eaf7: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/256e88c788c5f08f: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/8993e293a63bb5f3: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/1db0f571823145d8: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/05dab1fe544f0030: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/5af6dcedd96f0cc6: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/cb640b7dcc9db7e8: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/7f9b6c3dd5ed62d6: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/cb052007d1f07eea: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/95f0f46de0602a57: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/56807c93aa7cad79: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/36cc34108a238ba3: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/7f4fb0609c41af8b: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/f15c1bd6bbaf2be2: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/23af9fdc2bed3a68: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/d580cffa15744c99: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/f790562b8bcec824: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/dd42bc42222ffa64: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/e491dcf5c243c088: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/9a27064991a9e9d4: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/c0002de181334f3e: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/411e1f1e89c609fb: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/0eadf39171bd7e3e: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/5688f447e79de2a4: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/5d576cd36b515c03: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/68326025db2d8f2a: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/4dfc2840c97ffa71: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/ee1da0f9a06ea0ae: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/8b7f63980b08d2ce: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/109cdaeb21549bcc: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/34cd2d9b5eddf14f: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/0349606b5b992dec: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/83c354730b54cc61: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/9a1206b4e9413a74: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/b1aa2a2e7a56667b: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/4a4813e8407a2e0a: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/a3355e0d592bdbbc: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/e935a2b543d057e5: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/a41f67bc1174ad85: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/bcb38a9d29822d3d: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/8192d10021f932f9: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/54fb7dd9de96dfcf: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/bc7147fd7b8db8e9: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/d4ce05bd60e091d7: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/3c98de092f314d9e: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/b2313812d9a6ace9: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/3963c77bd1628165: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/b51131ac1f50b067: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/d9f0851db39067ec: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/bb738930036cfeba: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/b48fdc15154b542e: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/9ace397817d67f9e: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/4d7231ec867553d3: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/473ecef5e925971d: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/da7d61dfe3989093: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/f3e7ac4055e7a453: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/7332fecfd9ce88a6: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/fe7c434ced7759e5: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/4415c82e232471a9: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/bb4b3fc223c227b8: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/7f60017ac91f762b: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/43a6c66af55008ad: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/6d47fed801b6516d: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/787715a9030ddb2b: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/7d19db5befd8ddde: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/3459dd26c5ceb7d5: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/1ef98bfca49d53d5: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/2b277a2b1cb05660: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/31bd98c45d06a038: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/a3731e863522a698: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/f83616f226c0cffe: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/e754b5ac0b8c1c81: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/5c22963d44ab28e2: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/7458b1b3923fc2df: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/860ba4c51eca6a7d: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/f161d511b7a973fb: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/e8e483c38c643e66: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/dc51846a645f0428: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/aa96b8ec8e7266b4: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/88e09c269e38ad7e: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/e8ac219311ea7d0b: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/ef2d2eeca1652295: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/f2a79c82c850a474: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/66b5615704b18de0: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/815604a4d1b68cb6: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/582d3304aed63b1a: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/5b959d6c68d6daa0: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/27e7bfc9294eb37d: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/8fc5219c6e0e6dc6: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/dd5457699e3aca9c: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/209e1ac3966c6c41: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/7286a725cb39945b: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/5485d6f729e8b4b0: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/e22f3f1b19d4b51c: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/0c760ef7447f3252: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/39ce700e6cd0c49f: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/3c28c251bac3034b: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/b89c885da2c9bce4: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/ee84a0b122cd217a: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/024817f9b28943ab: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/526b3c44a3955726: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/d3fbdc3cb3efc7aa: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/76f349796a3862cc: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/9ebd955712f8e6e3: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/07005006dce71011: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/042ea219e5e46f84: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/f77022dfc627e121: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/b2f16264b43cd091: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/40c747f63d8cc6e9: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/898bb2a421ae58d6: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/46c89cdd835e002c: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/167ef9b08acba0a7: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/afe71c76155e7522: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/462650d0632a2258: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/996ddac74a29310e: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/ca52d846efa59f8d: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/73914b2b72c9f875: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/1ba7b5adb35da81a: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/6a2e067492347f51: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/b777e38b681f52de: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/6c846719d1f2c568: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/209c6e0c2f1bd12c: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/c2ed5a38a690b302: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/81354e750dd248fd: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/b0aee0248b292201: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/61fa503798568376: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/3618566df6c6a26e: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/b30407b833e96f96: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/f1b2f55ee43e3b8b: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/a4eb555e48847359: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/4146a71795a084f0: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/fd400f3417035734: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/eab2d9acc1b1cdc4: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/04eb7c9749f08f5b: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/9c84a8b814ed5a67: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/fc89b69a4fe79603: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/5732b6966c2232c4: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/df841d5b1365e039: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/dca56219c8655de8: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/59cd7bf7fe3f1c71: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/900890ef697e451a: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/bc0190e0e7f80d82: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/4fac31dde3f19b17: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/e08cd659a05f179c: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/b91ba570d5a8654d: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/12053410a45e4311: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/d3a95dc092a3b98e: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/d69249b26102b292: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/d029b7ec2d68d218: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/68cbd44208da19a5: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/0313e2800683dd9d: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/de4300c6c9900cca: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/7d7e4e72d08fb331: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/7a24961d33cd8fab: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/ddd86adc0b32fadc: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/8375ef15cf838b76: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/30a4a652eb4dbaaa: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/56674d151cf9b158: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/1b5f32e4fd52225b: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/773c36a7891b8567: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/a6f342e32f68ded6: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/5dafd35781c3a857: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/8c10733c97e01dc3: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/0e97df01e0df1a7f: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/bea0ed817fee7c74: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/25545fe0c7044932: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/9325bcf98fa2a15e: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/7d3927d916d95917: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/f26a29dd55c5a5cd: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/cc20ca955a263a58: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/c9f33133605acf22: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/97876bc571bd2b19: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/fff219fac94884d8: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/1f6cab1528ce6308: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/ce1ff42f030f424a: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/c73a91dcff319e6d: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/a75304045e10e061: cannot access local variable 'winner' where it is not associated with a value
# skip http://ufcstats.com/fight-details/9d5dce909eb0ab77: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/d0f2fb4dfac623a6: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/7a5534eae872c5ae: 'NoneType' object is not iterable
# skip http://ufcstats.com/fight-details/1216446c6ad271e7: cannot access local variable 'winner' where it is not associated with a value
